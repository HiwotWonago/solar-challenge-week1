# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\Hiwi\\Downloads\\CHIRPS_5_Countries_2018_2022.csv', encoding='ISO-8859-1')

# %%
df.shape
# Out:
# (900, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      900 non-null    object
#  1   Region       900 non-null    object
#  2   Year         900 non-null    int64
#  3   Month        900 non-null    int64
#  4   Rainfall_mm  900 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 35.3+ KB

# %%
df.head()
# Out:
#   Country   Region  Year  Month  Rainfall_mm
# 0   Kenya  Nairobi  2018      1        25.41
# 1   Kenya  Nairobi  2018      2       214.89
# 2   Kenya  Nairobi  2018      3       218.55
# 3   Kenya  Nairobi  2018      4       256.78
# 4   Kenya  Nairobi  2018      5       291.81

# %%
# Average rainfall per region per year
annual_rainfall = df.groupby(['Country', 'Region', 'Year'])['Rainfall_mm'].mean().reset_index()

# Pivot for plotting
pivot_df = annual_rainfall.pivot_table(index='Year', columns='Region', values='Rainfall_mm')
print(pivot_df)
# Out:
# Region     Abidjan      Abomey  Addis Ababa    Blantyre      Bouaké  \
# Year
# 2018    261.638333  190.125833   239.878333  190.078333  241.350000
# 2019    164.447500  145.474167   211.128333  217.766667  199.299167
# 2020    240.048333  209.790000   240.630000  220.358333  207.347500
# 2021    229.771667  261.400000   238.938333  220.095000  221.646667
# 2022    165.615000  211.065833   257.676667  199.375833  180.500833
#
# Region     Cotonou     Hawassa      Kisumu     Korhogo    Lilongwe  \
# Year
# 2018    181.955833  133.303333  189.781667  277.583333  149.459167
# 2019    164.214167  190.827500  184.508333  226.292500  210.955833
# 2020    169.050833  192.400833  247.877500  211.567500  186.661667
# 2021    153.787500  155.946667  227.047500  230.615000  161.233333
# 2022    179.756667  191.529167  232.690000  214.509167  238.860000
#
# Region     Mekelle     Mombasa       Mzuzu     Nairobi     Parakou
# Year
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=pivot_df)
plt.title('Average Annual Rainfall (mm) per Region: 2018–2022')
plt.ylabel('Rainfall (mm)')
plt.xlabel('Year')
plt.grid(True)
plt.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
